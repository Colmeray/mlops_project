# %%
from pathlib import Path

Path('hej_med_dig').mkdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 from pathlib import Path
# ----> 3 Path('hej_med_dig').mkdir()
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileExistsError: [Errno 17] File exists: 'hej_med_dig'
