# %%
from pathlib import Path
# import json

# p = Path("du_kender_mig")

# if not p.exists():
#     p.mkdir()

# (p / "what").write_text(json.dumps({
#     "classes" : {1 : 3 , 10 : 4} ,
#     "sigma_boy" : {"hej" : 3 , "hej2" : 4}
# } , indent= 2))

p1 = Path("hej/what/okay")
p2 = Path("hej/what/okay/du/banan")

p2.relative_to(p1).as_posix()
# Out:
# 'du/banan'
